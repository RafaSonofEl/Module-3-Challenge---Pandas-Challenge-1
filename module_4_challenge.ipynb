# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
df['category'].value_counts().head
# Out:
# <bound method NDFrame.head of category
# consumables    23538
# furniture      11915
# software        8400
# decor           7954
# electronics     2832
# Name: count, dtype: int64>

# %%
df.sort_values(by='qty', ascending=False)
# Out:
#            first      last                                  job  \
# 21801      Julie  Anderson                  Exhibition designer
# 25972        Amy   Stewart            Psychologist, educational
# 8761     Randall    Watson                    Ceramics designer
# 15112     Dennis   Hawkins  Social research officer, government
# 50048     Amanda   Burnett                      Records manager
# ...          ...       ...                                  ...
# 4444      Philip     Gates                         Photographer
# 21090     Daniel    Bowman                        Archaeologist
# 38593      Carla   Vazquez                        Site engineer
# 30396  Katherine    Hardin                  Magazine journalist
# 16820      Jared    Taylor                        Haematologist
#
#                         phone                                email  client_id  \
# 21801              5933099462        anderson_better_4704@bell.biz      78965
# ...

# %%
# What three item categories had the most entries? Answer: Consumables, furniture, software
df['category'].value_counts().head
# Out:
# <bound method NDFrame.head of category
# consumables    23538
# furniture      11915
# software        8400
# decor           7954
# electronics     2832
# Name: count, dtype: int64>

# %%
# For the category with the most entries,
# which subcategory had the most entries? Answer: bathroom supplies
df['subcategory'].value_counts().head
# Out:
# <bound method NDFrame.head of subcategory
# bathroom supplies     6424
# paper products        5874
# kitchen supplies      5746
# tables                4540
# misc                  4286
# stands                4201
# accounting            3756
# project management    3522
# plants                3466
# wall art              3093
# seating               2664
# pens                  2603
# logistics             1122
# telecom                978
# audio visual           732
# cabling                655
# desks                  510
# computers              467
# Name: count, dtype: int64>

# %%
# Which five clients had the most entries in the data? The clients with the most entries were: 33615, 66037, 46820, 38378, and 24741.
most_entries = df['client_id'].value_counts()
most_entries
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
#         ...
# 70734      4
# 32001      4
# 77583      3
# 76017      3
# 94987      1
# Name: count, Length: 999, dtype: int64

# %%
most_entries_clients = most_entries.sort_values(ascending=False)
most_entries_clients
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
#         ...
# 70734      4
# 32001      4
# 77583      3
# 76017      3
# 94987      1
# Name: count, Length: 999, dtype: int64

# %%
toptop = most_entries_clients.head(5)
toptop
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
top_clientele_df = ['33615', '66037', '46820', '38378', '24741']

# %%
# How many total units (the qty column) did the
# client with the most entries order order? Answer: 64,313
client_most_entries = df['client_id'].value_counts().idxmax()
client_most_entries
# Out:
# 33615

# %%
clientele_data = df[df['client_id'] == client_most_entries]
total_units_ordered = clientele_data['qty'].sum()
total_units_ordered
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty
df['subtotal'] = df['unit_price']* df['qty']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.
df['shipping_price'] = df['unit_weight'].apply(lambda x: 7 if x > 50 else 10)
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%

df['total_price'] = df['subtotal'] + df['shipping_price'] + (df['subtotal'] + df['shipping_price']) * 0.0925
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).
df['line_cost'] = df['unit_cost'] + df['shipping_price']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price
df['profit_line'] = df['line_cost'] + df['unit_cost']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
filtered_df = df[df['order_id'] == 2742071]
filtered_df
# Out:
#           first   last                                       job  \
# 3446   Kimberly  Blair  Geographical information systems officer
# 6287   Kimberly  Blair  Geographical information systems officer
# 20623  Kimberly  Blair  Geographical information systems officer
# 23840  Kimberly  Blair  Geographical information systems officer
# 24671  Kimberly  Blair  Geographical information systems officer
# 42470  Kimberly  Blair  Geographical information systems officer
#
#                     phone                           email  client_id  \
# 3446   477-680-9323x27378  blair.kimberly.6618@nelson.biz      78447
# 6287   477-680-9323x27378  blair.kimberly.6618@nelson.biz      78447
# 20623  477-680-9323x27378  blair.kimberly.6618@nelson.biz      78447
# 23840  477-680-9323x27378  blair.kimberly.6618@nelson.biz      78447
# 24671  477-680-9323x27378  blair.kimberly.6618@nelson.biz      78447
# 42470  477-680-9323x27378  blair.kimberly.6618@nelson.biz      78447
#
# ...

# %%
filtered_df = df[df['order_id'] == 2173913]
filtered_df
# Out:
#         first     last                 job                 phone  \
# 627    Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
# 14089  Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
# 14938  Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
# 14962  Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
# 22004  Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
# 27713  Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
# 53155  Darius  Stevens  Physicist, medical  +1-220-240-7019x2774
#
#                               email  client_id  order_id  order_date  \
# 627    stevensdarius@rich-leach.net      22122   2173913  2023-02-19
# 14089  stevensdarius@rich-leach.net      22122   2173913  2023-02-19
# 14938  stevensdarius@rich-leach.net      22122   2173913  2023-02-19
# 14962  stevensdarius@rich-leach.net      22122   2173913  2023-02-19
# 22004  stevensdarius@rich-leach.net      22122   2173913  2023-02-19
# ...

# %%
filtered_df = df[df['order_id'] == 6128929]
filtered_df
# Out:
#          first  last                       job                   phone  \
# 3422   Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 13672  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 14517  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 16295  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 21141  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 37265  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 37949  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 38542  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 48834  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
# 49353  Dorothy  Hall  Journalist, broadcasting  001-338-609-8495x03504
#
#                                         email  client_id  order_id  \
# 3422   dorothy.per.1343@mitchell-chambers.com      88257   6128929
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Aggregate total prices by 'Order ID'
order_totals = df.groupby('order_id')['total_price'].sum()

# %%
# Provided receipts as a dictionary for easy access
receipts = {
    2742071: 152811.89,
    2173913: 162388.71,
    6128929: 923441.25
}

# Check if the calculated totals match the receipts
for order_id, expected_total in receipts.items():
    calculated_total = order_totals.get(order_id, 0)
    print(f"Order ID {order_id}: Calculated Total = ${calculated_total:.2f}, Receipt Total = ${expected_total:.2f}")
    print("Match:", abs(calculated_total - expected_total) < 0.01)  # Check if the totals are nearly equal
# Out:
# Order ID 2742071: Calculated Total = $139686.32, Receipt Total = $152811.89
# Match: False
# Order ID 2173913: Calculated Total = $119640.51, Receipt Total = $162388.71
# Match: False
# Order ID 6128929: Calculated Total = $752365.71, Receipt Total = $923441.25
# Match: False

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# Aggregate total prices by 'Order ID'
client_id_totals = df.groupby('client_id')['total_price'].sum()

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.
receipts_two = {
    33615: 8377308.52,
    66037: 10259514.79,
    46820: 9743794.36,
    38378: 12906550.87,
    24741: 82268892.02
}

# Check if the calculated totals match the receipts
for client_id, expected_total in receipts_two.items():
    calculated_total = order_totals.get(client_id, 0)
    print(f"Client ID {client_id}: Calculated Total = ${calculated_total:.2f}, Receipt Total = ${expected_total:.2f}")
    print("Match:", abs(calculated_total - expected_total) < 0.01)  # Check if the totals are nearly equal
# Out:
# Client ID 33615: Calculated Total = $0.00, Receipt Total = $8377308.52
# Match: False
# Client ID 66037: Calculated Total = $0.00, Receipt Total = $10259514.79
# Match: False
# Client ID 46820: Calculated Total = $0.00, Receipt Total = $9743794.36
# Match: False
# Client ID 38378: Calculated Total = $0.00, Receipt Total = $12906550.87
# Match: False
# Client ID 24741: Calculated Total = $0.00, Receipt Total = $82268892.02
# Match: False

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
df['shipping_cost'] = df['unit_price'] * df['unit_weight']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
df['revenue'] = df['unit_price'] * df['qty']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
df['profit'] = df['revenue'] - df['shipping_cost']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
client_ids = [24741, 38378, 66037, 46820, 33615]
# Out:
# [24741, 38378, 66037, 46820, 33615]

# %%
select_client_ids = df[df['client_id'].isin(client_ids)]
select_client_ids
# Out:
#            first     last                                           job  \
# 5        Jessica    Reyes  Production designer, theatre/television/film
# 12       Jessica    Reyes  Production designer, theatre/television/film
# 137        Bryan    Myers                                Chief of Staff
# 214        Bryan    Myers                                Chief of Staff
# 216       Angela  Everett                                     Osteopath
# ...          ...      ...                                           ...
# 54535     Angela  Everett                                     Osteopath
# 54536     Kendra  Garrett                        Pension scheme manager
# 54579  Alexandra    Young                                     Dietitian
# 54589  Alexandra    Young                                     Dietitian
# 54613     Kendra  Garrett                        Pension scheme manager
#
#                   phone                            email  client_id  order_id  \
# ...

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.

summary = select_client_ids.groupby('client_id').agg(
    total_units_purchased=('qty', 'sum'),
    total_shipping_price=('shipping_cost', 'sum'),
    total_revenue=('revenue', 'sum'),
    total_profit=('profit', 'sum')
)

summary_sorted = summary.sort_values('total_profit', ascending=False)

print(summary_sorted)
# Out:
#            total_units_purchased  total_shipping_price  total_revenue  \
# client_id
# 24741                     239862           117085.8634    70176885.25
# 38378                      73667           195298.0011     8384321.15
# 66037                      43018           146014.7312     7995708.38
# 46820                      75768           145091.7210     7317356.03
# 33615                      64313           194843.9660     5839032.11
#
#            total_profit
# client_id
# 24741      7.005980e+07
# 38378      8.189023e+06
# 66037      7.849694e+06
# 46820      7.172264e+06
# 33615      5.644188e+06

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.
summary_sorted['total_shipping_price'] /= 1e6
summary_sorted['total_revenue'] /= 1e6
summary_sorted['total_profit'] /= 1e6

# %%
summary_sorted.rename(columns={
    'total_units_purchased': 'Total Units Purchased',
    'total_shipping_price': 'Total Shipping Price (millions)',
    'total_revenue': 'Total Revenue (millions)',
    'total_profit': 'Total Profit (millions)'
}, inplace=True)
summary_sorted
# Out:
#            Total Units Purchased  Total Shipping Price (millions)  \
# client_id
# 24741                     239862                         0.117086
# 38378                      73667                         0.195298
# 66037                      43018                         0.146015
# 46820                      75768                         0.145092
# 33615                      64313                         0.194844
#
#            Total Revenue (millions)  Total Profit (millions)
# client_id
# 24741                     70.176885                70.059799
# 38378                      8.384321                 8.189023
# 66037                      7.995708                 7.849694
# 46820                      7.317356                 7.172264
# 33615                      5.839032                 5.644188

# %%
# Sort the updated data by "Total Profit" form highest to lowest
# Out:
#    Client ID   Units Shipping Total Revenue Total Cost Total Profit
# 4      24741  239862   $5.13M       $82.27M    $45.69M      $36.58M
# 3      38378   73667   $3.43M       $12.91M     $9.63M       $3.27M
# 1      66037   43018   $1.40M       $10.26M     $7.00M       $3.26M
# 2      46820   75768   $1.60M        $9.74M     $7.01M       $2.74M
# 0      33615   64313   $1.83M        $8.38M     $6.18M       $2.20M
